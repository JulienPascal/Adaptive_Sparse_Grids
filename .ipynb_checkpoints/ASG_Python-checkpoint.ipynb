# %% [markdown]
# # The Curse of Dimensionality and Adaptive Sparse Grids
#
# **Julien Pascal: https://julienpascal.github.io/**
#
# Notebook for the **blog post here: https://julienpascal.github.io/post/asg/**
#
# ## Python version of the code
#
# With **Python**, I use the package **Tasmanian**:
#
# * https://pypi.org/project/Tasmanian/
#
# The first part of the code (test function) is based on this repo:
#
# * https://github.com/SparseGridsForDynamicEcon/SparseGrids_in_econ_handbook
#
# I made small modifications (e.g. vectorization of the code).
#
# ## I. Test function

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import copy
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [15, 9]

import Tasmanian # sparse grids
from copy import deepcopy
import numpy as np
from scipy.interpolate import RegularGridInterpolator #Linear interpoulation regular grid

from scipy.stats import norm, lognorm
import numpy as np
import chaospy #Numerical integration

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# Types of base functions for local sparse grids (see TASMANIAN documentation for
# more details)
#['localp', 'semi-localp', 'localp-zero', 'localp-boundary']

# Number of dimensions
gridDim = 2
# Number of outputs
gridOut = 1
# Grid level (note that counting starts at 0; we vary the level from 6 to 16)
gridDepthGrid = [5,6,7,8,9]
# 1=linear, 2=quadratic, 3=cubic
gridOrder = 1
# Type of base functions
gridRule = "localp"

# Domain of the grid (default for local grids is [-1,1]^n)
gridDomain = np.zeros((gridDim,2))
gridDomain[:,1] = 1.0

# Set random seed and number of draws
np.random.seed(seed=28092021)
TT = 10000

# Draw random numbers
evalPoints = np.random.rand(TT,gridDim)

# Number of distinct gridDepth values
noDepth = len(gridDepthGrid)

# Preallocation of error arrays
l1ErrorNSG = np.zeros(noDepth)
l2ErrorNSG = np.zeros(noDepth)
lInfErrorNSG = np.zeros(noDepth)
# Array to store the resp. number of grid points
NSGPoints = np.zeros(noDepth,dtype=int)

# Index for grid_depth
i0 = 0

# Adaptive Sparse Gridpoints
# Number of dimensions
gridDim = 2
# Number of outputs
gridOut = 1
# Grid level (we start with a sparse grid of level 3)
gridDepthASG = 2
# 1=linear, 2=quadratic, 3=cubic
gridOrder = 1
# Type of base functions
gridRule = "localp"

# Threshold for refinements
surplThreshold = 1e-5

# Preallocation of error arrays
l1ErrorNASG = np.zeros(noDepth)
l2ErrorNASG = np.zeros(noDepth)
lInfErrorNASG = np.zeros(noDepth)
# Array to store the resp. number of grid points
NASGPoints = np.zeros(noDepth,dtype=int)

# Loop over different possible refinement levels
for (i0, gridDepth) in enumerate(gridDepthGrid): 

    # Generate the grid structure
    gridNASG = Tasmanian.makeLocalPolynomialGrid(gridDim, gridOut, gridDepthASG, gridOrder,gridRule)
    # Transform the domain
    gridNASG.setDomainTransform(gridDomain)
    # Index of current grid level to control the number of refinements
    ilev = gridDepthASG

    while ((gridNASG.getNumNeeded() > 0) and (ilev<=gridDepth)):

        # Get the points that require function values
        aPointsNASG = gridNASG.getNeededPoints()
        # Get the number of points that require function values
        aNumAdd = gridNASG.getNumNeeded()

        # Preallocation of function values array
        fValuesNASG = np.zeros((aNumAdd,gridOut))

        # Non-vectorized
        #for i1 in range(aNumAdd): 
        #    fValuesNASG[i1] = 1.0/(np.abs(0.5 - aPointsNASG[i1,0]**4 - aPointsNASG[i1,1]**4) + 0.1)
        
        # Vectorized:
        fValuesNASG = 1.0/(np.abs(0.5 - aPointsNASG[:,0]**4 - aPointsNASG[:,1]**4) + 0.1)
        # Add a useless extra dimension for Tasmanian
        fValuesNASG = np.expand_dims(fValuesNASG, 1)
            
        # Load function values into the grid structure
        gridNASG.loadNeededPoints(fValuesNASG)
        
        # Refine the grid based on the surplus coefficients
        gridNASG.setSurplusRefinement(surplThreshold, -1, "classic")
        # Track the grid level
        ilev += 1
    
    # Store the number of grid points
    NASGPoints[i0] = gridNASG.getNumPoints()
    
    # Preallocation of arrays
    fTrueNASG = np.zeros(TT)
    fImpNASG = np.zeros(TT)

    # Random evaluation points
    fTrueNASG = 1.0/(np.abs(0.5 - evalPoints[:,0]**4 - evalPoints[:,1]**4) + 0.1)
    # Add a useless extra dimension for Tasmanian
    fTrueNASG = np.expand_dims(fTrueNASG, 1)
    # Interpolate the adaptive sparse grid at the random evaluation points
    fImpNASG = gridNASG.evaluateBatch(evalPoints)
        
    aPointsNASG_plot = gridNASG.getPoints()
    fValuesNASG_plot = gridNASG.getLoadedValues()

    fig = plt.figure(figsize=(16,8))
    # First subplot
    ax = fig.add_subplot(1,2,1)
    ax.scatter(aPointsNASG_plot[:,0],aPointsNASG_plot[:,1],marker='x',color='red',alpha=0.5)

    # Second subplot
    ax = fig.add_subplot(1,2,2, projection='3d')
    ax.scatter(aPointsNASG_plot[:,0],aPointsNASG_plot[:,1],fValuesNASG_plot,\
               marker='x',color='red',alpha=0.5)
    
    plt.title("Grid Depth: {}. Nb points: {}".format(gridDepth, len(fValuesNASG)))
    plt.show()
    
    # Compute the L1-error
    l1ErrorNASG[i0] = (1.0/TT)*np.sum(np.abs(fTrueNASG-fImpNASG))
    # Compute the L2-error
    l2ErrorNASG[i0] = ((1.0/TT)*np.sum(np.abs(fTrueNASG-fImpNASG)**2))**0.5
    # Compute the LInf-error as the 99.9 percent quantile of the error distribution
    lInfErrorOrder = np.sort(np.abs(fTrueNASG-fImpNASG),axis=None)
    lInfErrorNASG[i0] = np.amax(lInfErrorOrder[:-10])

# %%
plt.plot(gridDepthGrid, l1ErrorNASG, label="L1 error")
plt.plot(gridDepthGrid, l2ErrorNASG, label="L2 error")
plt.plot(gridDepthGrid, lInfErrorNASG, label="LInf error")
plt.legend()

# %% [markdown]
# ## II. Model
#
# See https://julienpascal.github.io/post/asg/ for details.

# %%
class Params:
    """
    A class to store model parameters and functions for the value function iteration problem.

    Attributes
    ----------
    x_min : float
        The minimum value of the x-axis.
    x_max : float
        The maximum value of the x-axis.
    y_min : float
        The minimum value of the y-axis.
    y_max : float
        The maximum value of the y-axis.
    nx : int
        Number of points in the x-axis grid.
    ny : int
        Number of points in the y-axis grid.
    nz : int
        Number of points in the z-axis grid.
    dt : float
        Time step.
    r : float
        Interest rate.
    delta : float
        Depreciation rate.
    epsilon : float
        A small constant to avoid boundary issues in the grid.
    x_grid : numpy.ndarray
        Grid points for the x-axis.
    y_grid : numpy.ndarray
        Grid points for the y-axis.
    rho : float
        Persistence parameter for the shock process.
    sigma : float
        Standard deviation of the shock process.
    psi : float
        Standard deviation of the innovation term in the shock process.
    distrib_innovation : chaospy.Distribution
        Distribution of the innovation term in the shock process.
    nb_nodes : int
        Number of nodes for the quadrature rule.
    nodes_E : numpy.ndarray
        Nodes for the expectation operator.
    weigths_E : numpy.ndarray
        Weights for the expectation operator.
    f0, f1, f2, f3, f4, f5, f6 : float
        Model parameters.
    b0 : float
        Parameter for the b_x function.
    z_min : float
        The minimum value of the z-axis.
    z_max : float
        The maximum value of the z-axis.
    lower_bound : list
        Lower bound for the state variables.
    upper_bound : list
        Upper bound for the state variables.
    z_grid : numpy.ndarray
        Grid points for the z-axis.
    nodes_xyz : tuple
        Grid points for the state variables.

    Methods
    -------
    p_xyz(x, y, z):
        Calculates the function p(x, y, z) for given x, y, and z.
    b_x(x):
        Calculates the function b(x) for given x.
    s_xyz(x, y, z):
        Calculates the function s(x, y, z) for given x, y, and z.
    """
    def __init__(self):
        self.x_min = 0.0
        self.x_max = 1.0
        self.y_min = 0.0
        self.y_max = 1.0
        self.nx = 21
        self.ny = 21
        self.nz = 10
        self.dt = 1.0 / 52.0
        self.r = (1.0 + 0.05) ** self.dt - 1.0
        self.delta = 0.0127012273
        self.epsilon = 0.001
        self.x_grid = np.linspace(self.x_min + self.epsilon, self.x_max - self.epsilon, self.nx)
        self.y_grid = np.linspace(self.y_min + self.epsilon, self.y_max - self.epsilon, self.ny)
        self.rho = 0.9997369438
        self.sigma = 0.0714488990
        self.psi = self.sigma * np.sqrt(1.0 - self.rho ** 2)
        self.distrib_innovation = chaospy.Normal(mu=0, sigma=self.psi)
        # Use chaopsy for the expectation operator
        self.nb_nodes = 10 #number nodes 
        # nodes and weigths
        self.nodes_E, self.weigths_E = chaospy.generate_quadrature(self.nb_nodes-1, self.distrib_innovation, rule ="gaussian")
        # Remove an extra dim to self.nodes_E
        self.nodes_E = self.nodes_E[0]
        self.f0 = 6.0873503685
        self.f1 = 0.0025488557
        self.f2 = 2.0529182143
        self.f3 = -0.1400252578
        self.f4 = 8.0349795180
        self.f5 = -1.9072145913
        self.f6 = 6.5961298483
        self.b0 = 0.7
        self.z_min = lognorm.ppf(0.05, self.sigma)
        self.z_max = lognorm.ppf(0.95, self.sigma)
        self.lower_bound = [self.x_min, self.y_min, self.z_min]
        self.upper_bound = [self.x_max, self.y_max, self.z_max]
        self.z_grid = np.linspace(self.z_min, self.z_max, self.nz)
        self.nodes_xyz = (self.x_grid, self.y_grid, self.z_grid)

    # Define your functions here as methods inside the Params class, using Python syntax.
    # For example:
    def p_xyz(self, x, y, z):
        return self.f0 * z * (self.f1 + self.f2 * x + self.f3 * y + self.f4 * (x ** 2) + self.f5 * (y ** 2) + self.f6 * x * y) * self.dt

    def b_x(self, x):
        return self.b0 * self.p_xyz(x, x, 1.0)

    def s_xyz(self, x, y, z):
        return self.p_xyz(x, y, z) - self.b_x(x)

# %%
p = Params()

# %%
np.sum(p.nodes_E)
# Out:
# -3.469446951953614e-18

# %%
p.weigths_E
# Out:
# array([4.31065263e-06, 7.58070934e-04, 1.91115805e-02, 1.35483703e-01,
#        3.44642335e-01, 3.44642335e-01, 1.35483703e-01, 1.91115805e-02,
#        7.58070934e-04, 4.31065263e-06])

# %%
# Non Vectorized code
# VERY SLOW
def solve_VFI(p: Params, max_iter: int = 1000, tol: float = 1e-8, show_every: int = None):
    """
    Solves the value function iteration (VFI) problem using a non-vectorized implementation on a dense grid.

    Parameters
    ----------
    p : Params
        An instance of the Params class containing model parameters and functions.
    max_iter : int, optional, default=1000
        Maximum number of iterations for the VFI algorithm.
    tol : float, optional, default=1e-8
        Convergence tolerance for the VFI algorithm.
    show_every : int, optional, default=None
        Frequency of displaying progress during the VFI algorithm.
        If None, it will only display progress at the end.

    Returns
    -------
    V_old_interpolated : function
        A function that returns interpolated values of the converged value function.

    Notes
    -----
    This non-vectorized implementation is computationally slow and may not be efficient for large grids.
    """
    V_old = np.zeros((p.nx, p.ny, p.nz))
    V_new = np.zeros((p.nx, p.ny, p.nz))

    # Initial guess
    for zIndex, zValue in enumerate(p.z_grid):
        for yIndex, yValue in enumerate(p.y_grid):
            for xIndex, xValue in enumerate(p.x_grid):
                V_old[xIndex, yIndex, zIndex] = p.s_xyz(xValue, yValue, zValue) + ((1.0 - p.delta)/(1.0 + p.r)) * max(0.0, p.s_xyz(xValue, yValue, zValue))

    itp = RegularGridInterpolator(p.nodes_xyz, V_old, method='linear', bounds_error=False, fill_value=None)
    
    def V_old_interpolated(x):
        x = np.atleast_2d(x)
        return itp(x)

    if show_every is None:
        show_every = max_iter

    # Main loop
    for i in range(1, max_iter + 1):
        for zIndex, zValue in enumerate(p.z_grid):
            for yIndex, yValue in enumerate(p.y_grid):
                for xIndex, xValue in enumerate(p.x_grid):
                    V_new[xIndex, yIndex, zIndex] = p.s_xyz(xValue, yValue, zValue) + ((1.0 - p.delta)/(1.0 + p.r)) * np.sum(p.weigths_E * np.array([np.maximum(0.0, V_old_interpolated([xValue, yValue, (zValue ** p.rho) * np.exp(innovation)])[0]) for innovation in p.nodes_E]))

        # Distance
        diff = np.max(np.abs(V_new - V_old))
        if i % show_every == 0:
            print(f"Iter {i} Diff : {diff}")

        if diff < tol:
            print(f"Iter {i} Convergence reached")
            break

        # Update
        V_old = np.copy(V_new)
        itp = RegularGridInterpolator(p.nodes_xyz, V_old, method='linear', bounds_error=False, fill_value=None)

    # Return value function
    return V_old_interpolated

# %%
# Vectorized code
def solve_VFI(p: Params, max_iter: int = 1000, tol: float = 1e-8, show_every: int = None):
    """
    Solve the value function iteration problem using vectorization for improved performance.

    Args:
        p (Params): An instance of the Params class, which contains the model's parameters.
        max_iter (int, optional): The maximum number of iterations to perform. Defaults to 1000.
        tol (float, optional): The tolerance for convergence. The iteration stops when the
            maximum difference between consecutive value function updates is less than `tol`.
            Defaults to 1e-8.
        show_every (int, optional): If specified, print the iteration number and the maximum
            difference between consecutive value function updates every `show_every` iterations.
            If not specified or None, this information is printed at every iteration.

    Returns:
        RegularGridInterpolator: An interpolator object that represents the solution to the
            value function iteration problem. This object can be used to interpolate the
            value function at arbitrary (x, y, z) points within the domain.
    """
    
    V_old = np.zeros((p.nx, p.ny, p.nz))
    V_new = np.zeros((p.nx, p.ny, p.nz))

    X, Y, Z = np.meshgrid(p.x_grid, p.y_grid, p.z_grid, indexing='ij')
    S = p.s_xyz(X, Y, Z)
    V_old = S + ((1.0 - p.delta) / (1.0 + p.r)) * np.maximum(0, S)

    if show_every is None:
        show_every = max_iter

    for i in range(1, max_iter + 1):
        itp = RegularGridInterpolator(p.nodes_xyz, V_old, method='linear', bounds_error=False, fill_value=None)

        V_old_innov_accum = np.zeros_like(V_old)

        for innovation, weight in zip(p.nodes_E, p.weigths_E):
            X_innov = X
            Y_innov = Y
            Z_innov = (Z ** p.rho) * np.exp(innovation)

            V_old_innov = itp(np.column_stack([X_innov.ravel(), Y_innov.ravel(), Z_innov.ravel()])).reshape(X_innov.shape)

            V_old_innov_accum += weight * np.maximum(0, V_old_innov)

        V_new = S + ((1.0 - p.delta) / (1.0 + p.r)) * V_old_innov_accum

        diff = np.max(np.abs(V_new - V_old))

        if i % show_every == 0:
            print(f"Iter {i} Diff : {diff}")

        if diff < tol:
            print(f"Iter {i} Convergence reached")
            break

        V_old = V_new.copy()

    return itp

# %%
# %%time
V_sol = solve_VFI(p, 5000, 1e-8, 50)
# Out:
# Iter 50 Diff : 0.35941383066083077
# Iter 100 Diff : 0.18029186493440363
# Iter 150 Diff : 0.09044289028266661
# Iter 200 Diff : 0.04537214987943372
# Iter 250 Diff : 0.022762534662668088
# Iter 300 Diff : 0.011420048930737892
# Iter 350 Diff : 0.005729690506306895
# Iter 400 Diff : 0.002874815723700408
# Iter 450 Diff : 0.001442461797644512
# Iter 500 Diff : 0.0007237922305662892
# Iter 550 Diff : 0.00036319398092388155
# Iter 600 Diff : 0.0001822545367957673
# Iter 650 Diff : 9.146035717577661e-05
# Iter 700 Diff : 4.589888606432169e-05
# Iter 750 Diff : 2.303488133748033e-05
# Iter 800 Diff : 1.1560703775614911e-05
# Iter 850 Diff : 5.802256332287925e-06
# Iter 900 Diff : 2.9122172975348803e-06
# Iter 950 Diff : 1.461721936379945e-06
# Iter 1000 Diff : 7.337021159514734e-07
# Iter 1050 Diff : 3.6828894423024394e-07
# Iter 1100 Diff : 1.8487210695639078e-07
# Iter 1150 Diff : 9.28042354075842e-08
# Iter 1200 Diff : 4.6588404245540005e-08
# Iter 1250 Diff : 2.3388444958527543e-08
# Iter 1300 Diff : 1.1741903449546953e-08
# Iter 1312 Convergence reached
# CPU times: user 11.7 s, sys: 0 ns, total: 11.7 s
# Wall time: 11.7 s

# %%
# Get V_sol values for z = 1.0
x_grid, y_grid = np.meshgrid(p.x_grid, p.y_grid)
z_fixed = np.ones_like(x_grid)
V_sol_z_fixed = V_sol(np.column_stack([x_grid.ravel(), y_grid.ravel(), z_fixed.ravel()])).reshape(x_grid.shape)

# Create a surface plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x_grid, y_grid, V_sol_z_fixed, cmap='viridis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('V_sol')
ax.set_title('V_sol for z = 1.0')
plt.show()

# %%
# Get V_sol values for z = 1.0
x_grid, y_grid = np.meshgrid(p.x_grid, p.y_grid)
z_fixed = np.ones_like(x_grid)
V_sol_z_fixed = V_sol(np.column_stack([x_grid.ravel(), y_grid.ravel(), z_fixed.ravel()])).reshape(x_grid.shape)

# Create a contour plot
fig, ax = plt.subplots()
contour = ax.contourf(x_grid, y_grid, V_sol_z_fixed, cmap='viridis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('V_sol Contour Plot for z = 1.0')
fig.colorbar(contour)
plt.show()

# %% [markdown]
# ## Sparse interpolation

# %%
def solve_VFI_sparse(p: Params, gridDepth: int = 3, NbRefinements: int = 4, surplThreshold: float = 1e-5, max_iter: int = 1000, tol: float = 1e-8, show_every: int = None):
    """
    Solves a value function iteration problem using an adaptive sparse grid approach.

    Parameters
    ----------
    p : Params
        An instance of the Params class, containing model parameters.
    gridDepth : int, optional, default=3
        The depth of the initial grid. Greater depth corresponds to a denser initial grid.
    NbRefinements : int, optional, default=4
        The number of refinement steps for the grid (inner loop).
    surplThreshold : float, optional, default=1e-5
        A parameter that defines which points are added to the grid when refining the grid (inner loop).
        The smaller the parameter, the fewer points are added to the grid.
    max_iter : int, optional, default=1000
        Maximum number of iterations for the value function iteration.
    tol : float, optional, default=1e-8
        Tolerance for convergence. If the maximum absolute difference between two consecutive value functions
        falls below this value, convergence is reached.
    show_every : int, optional, default=None
        Frequency of printing iteration information. If None, the information is printed only at the end.

    Returns
    -------
    grid_old : Tasmanian.makeLocalPolynomialGrid
        The final refined adaptive sparse grid with the converged value function.

    """
    gridDim = 3 #Dimension input
    gridOut = 1 #Dimension output
    gridOrder = 1 # 1=linear, 2=quadratic, 3=cubic
    gridRule = "localp" #Type of base functions
    
    grid_old = Tasmanian.makeLocalPolynomialGrid(gridDim, gridOut, gridDepth, gridOrder, gridRule)
    grid_old.setDomainTransform(np.array([p.x_min, p.x_max, p.y_min, p.y_max, p.z_min, p.z_max]).reshape(3, 2))

    # First interpolation
    aPoints = grid_old.getPoints()
    X, Y, Z = aPoints[:, 0], aPoints[:, 1], aPoints[:, 2]

    # Initial guess
    S = p.s_xyz(X, Y, Z)
    V_old = S + ((1.0 - p.delta) / (1.0 + p.r)) * np.maximum(0, S)
    V_old = np.expand_dims(V_old, 1)
    
    # First interpolation
    grid_old.loadNeededPoints(V_old)
    
    def V_old_interpolated(x):
        return grid_old.evaluateBatch(x)
    
    # Fixed grid to test for convergence
    x_grid, y_grid, z_grid = np.meshgrid(p.x_grid, p.y_grid, p.z_grid)
    
    # Test points:
    test_points = np.column_stack([x_grid.ravel(), y_grid.ravel(), z_grid.ravel()])
    V_old_test = V_old_interpolated(test_points).reshape(x_grid.shape)
        
    if show_every is None:
        show_every = max_iter

    # Loop for value function iteration
    convergence_reached = 0
    i=0
    while (convergence_reached == 0) and (i <= max_iter + 1):
        i+=2
        #print(i)
        # Loop over the adaptive sparse grid
        ilev = 0 #gridDepth

        # Loop for the refinement of the sparse grid:
        # Refinement based on the value of V_new
        grid_new = Tasmanian.makeLocalPolynomialGrid(gridDim, gridOut, gridDepth, gridOrder, gridRule)
        grid_new.setDomainTransform(np.array([p.x_min, p.x_max, p.y_min, p.y_max, p.z_min, p.z_max]).reshape(3, 2))
    
        # Keep track of the number of points on grid as we refine it
        num_points = [] 
        while ((grid_new.getNumNeeded() > 0) and (ilev<=NbRefinements)):
            ilev += 1
                
            aPoints = grid_new.getNeededPoints()
            aNumAdd = grid_new.getNumNeeded()
            
            num_points.append(aNumAdd)

            X, Y, Z = aPoints[:, 0], aPoints[:, 1], aPoints[:, 2]
            S = np.expand_dims(p.s_xyz(X, Y, Z), 1)
            
            V_old_innov_accum = np.zeros_like(S)

            for innovation, weight in zip(p.nodes_E, p.weigths_E):
                X_innov = X
                Y_innov = Y
                Z_innov = (Z ** p.rho) * np.exp(innovation)

                V_old_innov = V_old_interpolated(np.column_stack([X_innov.ravel(), Y_innov.ravel(), Z_innov.ravel()])).reshape(X_innov.shape)
                V_old_innov = np.expand_dims(V_old_innov, 1)       
                V_old_innov_accum += weight * np.maximum(0, V_old_innov)

            V_new = S + ((1.0 - p.delta) / (1.0 + p.r)) * V_old_innov_accum
            
            # Load function values into the grid structure
            grid_new.loadNeededPoints(V_new)
    
            # Refine
            grid_new.setSurplusRefinement(surplThreshold, -1, "classic")
            
             # Update the grid
            grid_old = grid_new
            
            # Update the interpolation object, including the new points 
            def V_old_interpolated(x):
                return grid_old.evaluateBatch(x)
            
        # Test new interpolation on a fixed grid
        V_new_test = V_old_interpolated(test_points).reshape(x_grid.shape)
        diff = np.max(np.abs(V_new_test - V_old_test))

        if i % show_every == 0:
            print(f"Iter {i} Diff : {diff}")

        if diff < tol:
            print(f"Iter {i} Convergence reached")
            print(f"ilev {ilev}")
            print(f"Num points across refinements: {num_points}")
            convergence_reached = 1

        #Update
        V_old_test = V_new_test.copy() 
        
    return grid_old

# %%
# %%time
grid_sol = solve_VFI_sparse(p, 3, 2, 1e-4, 5000, 1e-8, 50)
# Out:
# Iter 50 Diff : 0.5273399149767322
# Iter 100 Diff : 0.33688144309931545
# Iter 150 Diff : 0.21510024262374117
# Iter 200 Diff : 0.13763433856203022
# Iter 250 Diff : 0.08834842575993207
# Iter 300 Diff : 0.05691737978496292
# Iter 350 Diff : 0.03680570916974801
# Iter 400 Diff : 0.023874060832014266
# Iter 450 Diff : 0.015482566388733687
# Iter 500 Diff : 0.010107383539711634
# Iter 550 Diff : 0.006652064242171463
# Iter 600 Diff : 0.0045000691767853596
# Iter 650 Diff : 0.0030484034403315263
# Iter 700 Diff : 0.001960300505704282
# Iter 750 Diff : 0.0012781352269541912
# Iter 800 Diff : 0.0008389092724030434
# Iter 850 Diff : 0.0005533082061006667
# Iter 900 Diff : 0.0003665993871493356
# Iter 950 Diff : 0.00024382286704138778
# Iter 1000 Diff : 0.00016266875452686236
# Iter 1050 Diff : 0.00010904088514607224
# Iter 1100 Diff : 7.371758639962422e-05
# Iter 1150 Diff : 4.984481887859715e-05
# Iter 1200 Diff : 3.3707373937374996e-05
# Iter 1250 Diff : 2.2798361992926175e-05
# Iter 1300 Diff : 1.5423617714560578e-05
# Iter 1350 Diff : 1.043774456732649e-05
# Iter 1400 Diff : 7.066407338385261e-06
# Iter 1450 Diff : 4.7862359693340295e-06
# Iter 1500 Diff : 3.243561749854962e-06
# Iter 1550 Diff : 2.1994254630897103e-06
# Iter 1600 Diff : 1.4923785798259814e-06
# Iter 1650 Diff : 1.0133339607421021e-06
# Iter 1700 Diff : 6.88571137885674e-07
# Iter 1750 Diff : 4.682570988734369e-07
# Iter 1800 Diff : 3.1869408090301476e-07
# Iter 1850 Diff : 2.1708539676978944e-07
# Iter 1900 Diff : 1.4800134806591814e-07
# Iter 1950 Diff : 1.0099236291694069e-07
# Iter 2000 Diff : 6.897752058421247e-08
# Iter 2050 Diff : 4.7155175764146406e-08
# Iter 2100 Diff : 3.2267060134927306e-08
# Iter 2150 Diff : 2.222314776645362e-08
# Iter 2200 Diff : 1.5904213057638117e-08
# Iter 2250 Diff : 1.1365955288056284e-08
# Iter 2270 Convergence reached
# ilev 3
# Num points across refinements: [69, 107, 151]
# CPU times: user 1min 21s, sys: 80.8 ms, total: 1min 21s
# Wall time: 6.85 s

# %%
def V_sol_sparse(x):
    return grid_sol.evaluateBatch(x)

aPoints = grid_sol.getNeededPoints()

X, Y, Z = aPoints[:, 0], aPoints[:, 1], aPoints[:, 2]

V_sol_z_fixed = V_sol(np.column_stack([X.ravel(), Y.ravel(), Z.ravel()*1.0])).reshape(X.shape)

fig = plt.figure(figsize=(16,8))
# First subplot
ax = fig.add_subplot(1,2,1)
ax.scatter(aPoints[:,0],aPoints[:,1],marker='x',color='red',alpha=0.5)

# Second subplot
ax = fig.add_subplot(1,2,2, projection='3d')
ax.scatter(aPoints[:,0], aPoints[:,1], V_sol_z_fixed, marker='x',color='red',alpha=0.5)

# %%
# Second subplot
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(1,1,1, projection='3d')
ax.scatter(aPoints[:,0], aPoints[:,1],  aPoints[:,2], marker='x',color='red',alpha=0.5)
plt.show()

# %%
plt.rcParams['figure.figsize'] = [9, 15]

# Get V_sol values for z = 1.0
x_grid, y_grid = np.meshgrid(p.x_grid, p.y_grid)
z_fixed = np.ones_like(x_grid)
V_sol_z_fixed = V_sol_sparse(np.column_stack([x_grid.ravel(), y_grid.ravel(), z_fixed.ravel()])).reshape(x_grid.shape)

# Create a surface plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x_grid, y_grid, V_sol_z_fixed, cmap='viridis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('V_sol')
ax.set_title('V_sol for z = 1.0')
plt.show()
